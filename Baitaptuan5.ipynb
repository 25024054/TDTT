# %% [markdown]
# ### W5A1 Viết hàm truyền vào hai số nguyên a, b. Trả về số lớn hơn trong hai số. def Max_Of_Two( a, b) ->int:

# %%
def Max_Of_Two(a,b):
 if a>b:
    return a
 if a<=b:
    return b
print(Max_Of_Two(5,6))
# Out:
# 6

# %% [markdown]
# ### W5A2-Viết hàm hoán đổi hai số nguyên. def swap(a, b) -> Tuple[int, int]:

# %%
def exchange(a,b):
 return b,a
print(exchange(9,8))
# Muốn bỏ dấu ngoặc thì thêm * trước exchange
# Out:
# 8 9

# %% [markdown]
# ### W5A3 Viết hàm kiểm tra một số có phải là số nguyên tố hay không?

# %%
def prime_number(a):
 if a<2:
  return False
 else:
  for i in range(2,a):
   if a%i==0:
    return False
  else:
   return True
print(prime_number(9))
# Out:
# False

# %% [markdown]
# ### W5A4 VIết hàm kiểm tra một số có phải số hoàn hảo hay không, xử lý trên dữ liệu kiểu số nguyên.

# %%
def perfect_number(a):
 if a<=1:
  return False
 else:
  x=0
  for i in range(1,a):
   if a%i==0:
    x=x+i
  if x==a:
   return True
  else:
   return False
print(perfect_number(7))
# Out:
# False

# %% [markdown]
# ### W5A5 Viết hàm đưa vào một list số nguyên và một số nguyên dương k. Hãy tìm và trả về vị trí của phần tử đầu tiên có giá trị k trong list số nguyên, nếu không có thì trả về -1

# %%
def find_k(list_songuyen,a):
 for i in range(len(list_songuyen)):
  if list_songuyen[i]==a:
   return i+1
 else:
  return -1
print(find_k([1,2,3,4,0,9,8,8],0))
# Out:
# 5

# %% [markdown]
# ### W5A6 Viết hàm tính giai thừa. Nhập vào số nguyên n, trả về giai thừa của n (n!)

# %%
def giaithua(a):
 x=1
 for i in range(1,a+1):
  x=x*i
 return x
print(giaithua(3))
# Out:
# 6

# %% [markdown]
# ### W5A7 Viết hàm giả lập một máy tính bỏ túi. Hàm thực hiện tính toán kết quả của phép toán giữa số \( num1 \) và \( num2 \) với toán tử \( operat \) Biết các toán tử đơn giản thực hiện phép toán lần lượt là:
# Phép trừ \( - \)
# Phép cộng \( + \)
# Phép chia \( / \)
# Phép nhân \( * \)
# Kết quả làm tròn đến chữ số thập phân thứ hai.
# Đầu vào: Hai số thực và phép toán cần thực hiện (trong số các phép toán \(+, -, *, /\)).
# Đầu ra: Kết quả phép toán

# %%
def pheptoan(num1,num2,op):
 if op=="*":
  return round(num1*num2,2)
 elif op=="+":
  return round(num1+num2,2)
 elif op=="-":
  return round(num1-num2,2)
 elif op=="/":
  if num2!=0:
   return round(num1/num2,2)
  elif num2==0:
   return "Error"
print(pheptoan(3.244,3,"+"))
# Out:
# 6.24

# %% [markdown]
# ### W5A8 Khoảng cách Hamming giữa hai số nguyên là số lượng vị trí khác nhau giữa hai dãy bits tương ứng của chúng. Ví dụ: Khoảng cách Hamming giữa 1 (1) và 4 (100) là 2. Cho hai số nguyên  x và y, hãy viết hàm trả về khoảng cách Hamming giữa hai số này.

# %%
def hamming(a,b):
 x=0
 c=a^b
 for i in bin(c):
  if i=="1":
   x=x+1
 return(x)
print(hamming(8,10))
# hàm bin chuyển số nguyên sang nhị phân
#hamming là số lần khác nhau trong 2 bit
#hàm xor trả về 1 số nguyên kiểu: 1011....
# Out:
# 1

# %% [markdown]
# ### W5A9 Viết hàm trả về tổng các chữ số của số nguyên dương n

# %%
def tong(n):
 x=0
 for i in str(n):
  x=x+int(i)
 return x
print(tong(123))
# Out:
# 6

# %% [markdown]
# ### W5A10 Hai từ được gọi là đẳng cấu nếu các kí tự trong một từ có thể được ánh xạ để được từ còn lại. Ánh xạ một kí tự nghĩa là thay đổi toàn bộ các kí tự đó trong từ bởi một kí tự khác. Thứ tự của các kí tự được giữ không đổi. Hai kí tự khác nhau không thể ánh xạ đến cùng một kí tự, nhưng một kí tự có thể ánh xạ thành chính nó. Ví dụ, từ "abca" và "zbxz" là hai từ đẳng cấu vì ta có thể ánh xạ 'a' thành 'z', 'b' thành 'b' và 'c' thành 'x'. Viết hàm  trả về \(true\) nếu hai từ \(a\) và \(b\) là đẳng cấu, ngược lại \(false\). Bạn có thể giả sử hai từ đầu vào có cùng độ dài.

# %%
def dangcau(a, b):
    dict = {}
    for i in range(len(a)):
        char_a = a[i]  
        char_b = b[i]  # các ss 2 vị trí trong 2 ds
        if char_a in dict:
            if dict[char_a] != char_b:
                return False
        else:
            if char_b in dict.values():   #dict.value() để ktr char_b đã đc nối vs char_a nào hay ch
                return False
            dict[char_a] = char_b
    return True
print(dangcau("aa","xy"))
# Out:
# False

# %% [markdown]
# ### W5A11 Viết hàm is_product_divisible_by_10(a, b) trả về True nếu tích a*b chia hết cho 10, ngược lại False.

# %%
def is_product_divisible_by_10(a, b):
 if (a*b)%10==0:
  return True
 else:
  return False
print(is_product_divisible_by_10(2,11))
# Out:
# False

# %% [markdown]
# ### W5A12 Viết hàm divide_with_remainder(dividend, divisor) trả về bộ (q, r) sao cho dividend = divisor*q + r và 0 <= |r| < |divisor|.

# %%
def divide_with_remainder(dividend, divisor):
 return dividend//divisor ,dividend%divisor
print(divide_with_remainder(5,4))
# Out:
# (1, 1)

# %% [markdown]
# ### W5A13 Viết hàm max_of_two(a, b) trả về số lớn hơn trong hai số.

# %%
def max_of_two(a,b):
 if a>=b:
  return a
 if a<b:
  return b
print(max_of_two(8,9))
# Out:
# 9

# %% [markdown]
# ### W5A14 Viết hàm compute(a, b, op) thực hiện phép tính a (+|-|*|/) b tùy theo ký tự op.

# %%
def compute(a,b,op):
 if op=="*":
  return a*b
 elif op=="+":
  return a+b
 elif op=="-":
  return a-b
 elif op=="/":
  if b!=0:
   return a/b
  elif b==0:
   return Error
print(compute(2,3,"+"))
# Out:
# 5

# %% [markdown]
# ### W5A15 Viết hàm is_right_triangle(a, b, c) trả về True nếu ba số có thể là ba cạnh của tam giác vuông

# %%
def is_right_triangle(a, b, c):
 if a+b>c and a+c>b and b+c>a:
  if (a**2)+(b**2)==c**2 or (b**2)+(c**2)==a**2 or (a**2)+(c**2)==b**2:
   return True
  else:
   return False
 else:
  return "Error"
print(is_right_triangle(3,3,6))
# Out:
# Error
