# %% [markdown]
# ### W3A1-Nhập vào một số nguyên dương có 3 chữ số. Tìm và in ra màn hình “SỐ NGUYÊN” đảo ngược của n. Không dùng kiểu chuỗi. Chú ý: kiểm tra chỉ xử lý các số nguyên dương có đúng 3 chữ số. Các số khác không xử lý.

# %%
a=(input())
print(a[::-1])
# Out:
# 987654321

# %% [markdown]
# ### W3A2-Hoán đổi hai số không sd biến tạm thời Sử dụng phép toán XOR trên bit để hoán đổi giá trị của hai biến.

# %%
a=int(input())
b=int(input())
a,b=b,a
print(f"{a} {b}")
# Out:
# (2 1)

# %% [markdown]
# ### W3A3-Kiểm tra xem một số có phải là lũy thừa của 2 hay không .Sử dụng các toán tử bitwise để xác định xem một số có phải là lũy thừa của 2 hay không.

# %%
n=int(input())
if n>0 and (n&(n-1))==0:
 print("True")
else:
 print("False")
# Out:
# True

# %% [markdown]
# ### W3A4-Viêt chương trình chia một số m cho n, kết quả thu được làm tròn xuống

# %%
m=int(input())
n=int(input())
if m/n>=0:
 if m/n==int(m/n):
  print((m/n))
 elif m/n!=int(m/n):
  print(int(m/n))
elif m/n<0:
 if m/n==int(m/n):
  print((m/n))
 elif m/n!=int(m/n):
  print(int(m/n)-1)

# %% [markdown]
# ### W3A5-Viêt chương trình chia một số m cho n, kết quả thu được làm tròn lên

# %%
m=int(input())
n=int(input())
if m/n>=0:
 if m/n==int(m/n):
  print((m/n))
 elif m/n!=int(m/n):
  print(int(m/n)+1)
elif m/n<0:
 if m/n==int(m/n):
  print((m/n))
 elif m/n!=int(m/n):
  print(int(m/n))
# Out:
# -2

# %% [markdown]
# ### W3A6-Nhập vào một số nguyên dương x, bạn hãy kiểm tra xem x là số chẵn hay lẻ.Nếu x là số chẵn, in ra "Even". Nếu x là số lẻ, in ra "Odd".

# %%
a=int(input())
if a%2==0:
 print("Even")
else:
 print("Odd")
# Out:
# Even

# %% [markdown]
# ### W3A7-Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in ra "No".

# %%
a=int(input())
b=int(input())
if a<0 and b<0:
 print("Yes")
else:
 print("No")
# Out:
# Yes

# %% [markdown]
# ### W3A8-Nhập vào hai chuỗi a, b gồm các chữ cái thường. In ra "True" nếu chuỗi a dài hơn chuỗi b. Ngược lại in ra "False".

# %%
a=input()
b=input()
if len(a)>len(b):
 print("True")
elif len(b)>len(a):
 print("False")
# Out:
# True

# %% [markdown]
# ### W3A9-Nhập vào 3 số nguyên dương a, b, c. Kiểm tra xem a, b, c có cấu thành độ dài cạnh của 1 tam giác được không. Nếu a, b, c cấu tạo thành được một tam giác, in ra "Yes". Ngược lại in ra "No".

# %%
a=int(input())
b=int(input())
c=int(input())
if a+c>b or a+b>c or b+c>a:
 print("Yes")
else:
 print("No")
# Out:
# Yes

# %% [markdown]
# ### W3A10-Nhập vào 4 số nguyên. In ra màn hình số nguyên lớn nhất trong 4 số.

# %%
a=int(input())
b=int(input())
c=int(input())
d=int(input())
if b>a:
 max1=b
else:
 max1=a
if c>d:
 max2=c
else:
 max2=d
if max1>max2:
 print(max1)
else:
 print(max2)
# Out:
# 4

# %% [markdown]
# ### W3A11-Nhập vào 3 số nguyên dương a,b,c là độ dài 3 cạnh của một tam giác. Kiểm tra 3 số đã nhập có tạo thành một tam giác hợp lệ hay không. Nếu không in ra "Không phải tam giác". Nếu có, phân loại tam giác đó là "Tam giác đều","Tam giác cân", hay "Tam giác thường".

# %%
a=int(input())
b=int(input())
c=int(input())
if a+c>b or a+b>c or b+c>a:
 if a==b==c:
  print("Tam giac deu")
 elif a==b!=c or a==c!=b or b==c!=b:
  print("tam giac can")
 else:
  print("tam giac thuong")
else:
 print("Khong phai tam giac")
# Out:
# tam giac thuong

# %% [markdown]
# ### W3A12-Nhập vào một số nguyên dương n là số năm, kiểm tra xem năm đó có phải là năm nhuận hay không. Năm nhuận là năm chia hết cho 4 nhưng không chia hết cho 100, hoặc chia hết cho 400. Nếu là năm nhuận in ra "Yes", nếu không in ra "No"

# %%
a=int(input())
if a%4==0 and a%100!=0 or a%400==0:
 print("yes")
else:
 print("No")
# Out:
# yes

# %% [markdown]
# ### W3A14-Nhập vào hai số thực a và b của phương trình ax + b = 0. Tìm và in ra nghiệm của phương trình, kết quả làm tròn đến số thập phân thứ 2. In ra "Vô nghiệm" hoặc "Vô số nghiệm" trong trường hợp tương ứng.

# %%
a=int(input())
b=int(input())
if a==0 and b==0:
 print("vo so nghiem")
if a==0 and b!=0:
 print("vo nghiem")
else:
 print(f"{(-b/a):.2f}")
# Out:
# -1.20

# %% [markdown]
# ### W3A15-Nhập vào điểm trung bình của một học sinh và in ra học lực của học sinh đó.Xếp loại học lực theo quy tắc:
#  >= 8.0: Giỏi
#  >=6.5: Khá
#  >= 5.0: Trung bình
# < 5.0: Yếu

# %%
a=int(input())
if a>=8:
 print("gioi")
elif a>=6.5:
 print("kha")
elif a>=5:
 print("trung binh")
elif a<5:
 print("yeu")
# Out:
# trung binh

# %% [markdown]
# ### W3A16-Nhập vào một số thực: in ra kết quả làm tròn lên, tròn xuống, làm tròn tới số nguyên gần nhất (không được sử dụng hàm sẵn có của pyton). Các kết quả cách nhau một dấu cách

# %%
m=float(input())
if m>=0:
 if m==int(m):
  print(int(m),int(m),int(m),sep=" ")
 elif m!=int(m) and m-int(m)>=0.5:
  print(int(m)+1,int(m),int(m)+1,sep=" ")
 elif m!=int(m) and m-int(m)<0.5:
  print(int(m)+1,int(m),int(m),sep=" ")
elif m<0:
 if m==int(m):
  print(int(m))
 elif m!=int(m)and m-int(m)>=-0.5:
  print(int(m),int(m)-1,int(m),sep=" ")
 elif m!=int(m)and m-int(m)<-0.5:
  print(int(m),int(m)-1,int(m)-1,sep=" ")
# Out:
# -2 -3 -2

# %% [markdown]
# ### W3A17-Cấp số nhân
# Cho 4 số a, b, c, d. Hãy kiểm tra xem 4 số này có thể theo thứ tự tạo thành 1
# cấp số nhân với công bội nguyên theo đúng thứ tự a, b, c, d hay không?
# Gợi ý : Tìm công bội (b / a) nếu b chia hết cho a, sau đó lấy b nhân công bội
# và so sánh vs c, c nhân công bội và so sánh vs d.

# %%
a,b,c,d=map(float,input().split())
if b%a==c%b==d%c==0:
 if b*(b/a)==c and c*(b/a)==d:
  print("La csn voi cong boi ",int(b/a))
else:
 print("khong phai cong boi nguyen")
# Out:
# La csn voi cong boi  3
